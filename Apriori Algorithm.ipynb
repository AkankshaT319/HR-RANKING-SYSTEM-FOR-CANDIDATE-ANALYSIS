# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

# %%
df = pd.read_csv("HR_data.csv") 
df.head()
# Out:
#    SLNO  Candidate.Ref DOJ.Extended  Duration.to.accept.offer  Notice.period  \
# 0     1        2110407          Yes                        14             30
# 1     2        2112635           No                        18             30
# 2     3        2112838           No                         3             45
# 3     4        2115021           No                        26             30
# 4     5        2115125          Yes                         1            120
#
#   Offered.band  Pecent.hike.expected.in.CTC  Percent.hike.offered.in.CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
# ...

# %%
# Apply Apriori Algorithm
#Importing Apriori Algorithm Association


#LOB is Line of Business


import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
#Support:

#The support of item I is defined as the ratio between the
#number of transactions containing the item I by the total number of transactions expressed as :


#Confidence:

#This is measured by the proportion of transactions with item I1, in which item I2 also appears. 
#The confidence between two items I1 and I2, in a transaction is defined
#as the total number of transactions containing both items I1 and I2 divided by the total number of transactions containing I1.


#Lift:

#Lift is the ratio between the confidence and support

# %%
#Renaming the Columne
df = df.rename(columns={'Candidate.Ref':'Candidate_ref', 'DOJ.Extended':'DOJ_extended', 'Duration.to.accept.offer':'Accept_duration',
       'Notice.period':'Notice_period', 'Offered.band':'Offered_band', 'Pecent.hike.expected.in.CTC':'Percent_hike_expected',
       'Percent.hike.offered.in.CTC':'Percent_hike_offered', 'Percent.difference.CTC':'Percent_difference',
       'Joining.Bonus':'Joining_Bonus', 'Candidate.relocate.actual':'Relocated','Candidate.Source':'Source','Rex.in.Yrs':'Rex'})

# %%
df
# Out:
#        SLNO  Candidate_ref DOJ_extended  Accept_duration  Notice_period  \
# 0         1        2110407          Yes               14             30
# 1         2        2112635           No               18             30
# 2         3        2112838           No                3             45
# 3         4        2115021           No               26             30
# 4         5        2115125          Yes                1            120
# ...     ...            ...          ...              ...            ...
# 8990  12319        3822427           No                4              0
# 8991  12327        3828206          Yes                2              0
# 8992  12331        3834159           No                0              0
# 8993  12332        3835433           No                0             30
# 8994  12333        3836076           No                2              0
#
#      Offered_band  Percent_hike_expected  Percent_hike_offered  \
# ...

# %%
Aprior_str = df.groupby(['Offered_band', 'Location'])['Location'].count().reset_index(name ='Count')
Aprior_str
# Out:
#    Offered_band   Location  Count
# 0            E0  Bangalore     10
# 1            E0    Chennai     70
# 2            E0    Kolkata      1
# 3            E0      Noida    130
# 4            E1  Ahmedabad      5
# 5            E1  Bangalore   1550
# 6            E1    Chennai   2145
# 7            E1     Cochin      7
# 8            E1    Gurgaon     97
# 9            E1  Hyderabad    177
# 10           E1    Kolkata     74
# 11           E1     Mumbai    116
# 12           E1      Noida   1351
# 13           E1     Others     12
# 14           E1       Pune     34
# 15           E2  Ahmedabad      1
# 16           E2  Bangalore    580
# 17           E2    Chennai    807
# 18           E2     Cochin      1
# 19           E2    Gurgaon     47
# 20           E2  Hyderabad    135
# 21           E2    Kolkata     46
# 22           E2     Mumbai     72
# 23           E2      Noida   1010
# 24           E2     Others      1
# 25           E2       Pune     11
# ...

# %%
# Transactions done in Mumbai
Aprior_Mumbai = (df[df['Location'] =="Mumbai"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Mumbai
# Out:
#             LOB  Percent_hike_offered Offered_band  Count
# Location
# Mumbai     BFSI                  7.00           E2      1
# Mumbai     BFSI                  7.69           E1      1
# Mumbai     BFSI                 15.38           E1      1
# Mumbai     BFSI                 20.33           E2      1
# Mumbai     BFSI                 26.29           E2      1
# ...         ...                   ...          ...    ...
# Mumbai    INFRA                100.00           E1      1
# Mumbai    INFRA                100.00           E2      1
# Mumbai    INFRA                104.55           E1      1
# Mumbai    INFRA                105.00           E1      1
# Mumbai    INFRA                138.10           E1      1
#
# [167 rows x 4 columns]

# %%
# Transactions done in Others
Aprior_Others = (df[df['Location'] =="Other"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Others
# Out:
# Empty DataFrame
# Columns: [LOB, Percent_hike_offered, Offered_band, Count]
# Index: []

# %%
# Transactions done in Pune
Aprior_Pune = (df[df['Location'] =="Pune"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Pune
# Out:
#             LOB  Percent_hike_offered Offered_band  Count
# Location
# Pune       BFSI                  0.00           E2      1
# Pune       BFSI                 18.40           E2      1
# Pune       BFSI                 33.33           E2      1
# Pune       BFSI                 41.88           E2      1
# Pune       CSMP                 24.44           E2      1
# Pune        EAS                 13.04           E2      1
# Pune        ERS                  0.00           E1      1
# Pune        ERS                  0.00           E2      1
# Pune        ERS                  1.67           E1      1
# Pune        ERS                  4.65           E1      1
# Pune        ERS                 22.73           E1      1
# Pune        ERS                 22.87           E1      1
# Pune        ERS                 23.08           E1      1
# Pune        ERS                 25.87           E1      1
# Pune        ERS                 27.27           E2      1
# ...

# %%
# Transactions done in Cochin
Aprior_Cochin =  (df[df['Location'] =="Cochin"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Cochin
# Out:
#             LOB  Percent_hike_offered Offered_band  Count
# Location
# Cochin    INFRA                -16.67           E1      1
# Cochin    INFRA                -10.00           E1      1
# Cochin    INFRA                 23.70           E2      1
# Cochin    INFRA                 33.34           E1      1
# Cochin    INFRA                 42.86           E1      3
# Cochin    INFRA                 44.44           E1      1

# %%
# Transactions done in KolKata
Aprior_KolKata = (df[df['Location'] =="KolKata"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_KolKata
# Out:
# Empty DataFrame
# Columns: [LOB, Percent_hike_offered, Offered_band, Count]
# Index: []

# %%
# Transactions done in Hydrabad
Aprior_Hydrabad =  (df[df['Location'] =="Hydrabad"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Hydrabad
# Out:
# Empty DataFrame
# Columns: [LOB, Percent_hike_offered, Offered_band, Count]
# Index: []

# %%
# Transactions done in BANALORE
Aprior_Bangalore = (df[df['Location'] =="Bangalore"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Bangalore
# Out:
#              LOB  Percent_hike_offered Offered_band  Count
# Location
# Bangalore   AXON                -33.33           E1      1
# Bangalore   AXON                 -7.78           E1      1
# Bangalore   AXON                 -6.35           E1      1
# Bangalore   AXON                 -5.34           E2      1
# Bangalore   AXON                 -4.76           E2      1
# ...          ...                   ...          ...    ...
# Bangalore  INFRA                205.00           E2      1
# Bangalore  INFRA                253.82           E3      1
# Bangalore  INFRA                257.14           E3      1
# Bangalore  INFRA                393.33           E2      1
# Bangalore    MMS                 42.11           E1      1
#
# [1510 rows x 4 columns]

# %%
# Transactions done in Gurgaon
Aprior_Gurgaon =  (df[df['Location'] =="Gurgaon"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Gurgaon
# Out:
#             LOB  Percent_hike_offered Offered_band  Count
# Location
# Gurgaon    BFSI                -22.22           E1      1
# Gurgaon    BFSI                 -1.79           E1      1
# Gurgaon    BFSI                  0.00           E1      1
# Gurgaon    BFSI                  4.76           E2      1
# Gurgaon    BFSI                  6.67           E1      1
# ...         ...                   ...          ...    ...
# Gurgaon   INFRA                 68.25           E2      1
# Gurgaon   INFRA                 81.82           E1      1
# Gurgaon   INFRA                 99.13           E1      1
# Gurgaon   INFRA                110.00           E2      1
# Gurgaon   INFRA                124.54           E1      2
#
# [125 rows x 4 columns]

# %%
# Transactions done in Chennai
Aprior_Chennai =  (df[df['Location'] =="Chennai"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Chennai
# Out:
#            LOB  Percent_hike_offered Offered_band  Count
# Location
# Chennai   AXON                -36.36           E2      1
# Chennai   AXON                -18.07           E2      1
# Chennai   AXON                -14.29           E2      1
# Chennai   AXON                  0.00           E1      1
# Chennai   AXON                  2.86           E1      1
# ...        ...                   ...          ...    ...
# Chennai    MMS                 57.50           E1      1
# Chennai    MMS                 58.86           E1      1
# Chennai    MMS                 60.00           E1      1
# Chennai    MMS                 66.67           E1      1
# Chennai    MMS                 74.29           E1      1
#
# [2095 rows x 4 columns]

# %%
# Transactions done in Noida
Aprior_Noida =  (df[df['Location'] =="Noida"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Noida
# Out:
#             LOB  Percent_hike_offered Offered_band  Count
# Location
# Noida      AXON                -10.38           E2      1
# Noida      AXON                 -9.73           E3      1
# Noida      AXON                 -8.23           E2      1
# Noida      AXON                 -7.69           E1      1
# Noida      AXON                 -7.59           E2      1
# ...         ...                   ...          ...    ...
# Noida     INFRA                287.50           E2      2
# Noida     INFRA                314.53           E2      1
# Noida     INFRA                400.00           E3      1
# Noida       MMS                 21.62           E1      1
# Noida       MMS                 71.43           E1      1
#
# [1662 rows x 4 columns]

# %%
Aprior_Ahmedabad = (df[df['Location'] =="Ahmedabad"]
          .groupby(['Location', 'LOB','Percent_hike_offered','Offered_band'])['Gender']
          .count().reset_index(name='Count').fillna(0)
          .set_index('Location'))
Aprior_Ahmedabad
# Out:
#              LOB  Percent_hike_offered Offered_band  Count
# Location
# Ahmedabad  INFRA                -30.40           E1      1
# Ahmedabad  INFRA                -10.00           E1      1
# Ahmedabad  INFRA                  0.00           E1      1
# Ahmedabad  INFRA                 22.63           E1      1
# Ahmedabad  INFRA                 42.86           E1      1
# Ahmedabad  INFRA                 64.32           E2      1

# %%
# making a mxn matrice where m=Location and n=SLNO and each row represents whether the SLNO was in the Same location or not
DATA = Aprior_str.pivot_table(index='Location', columns='Offered_band', values='Count').fillna(0)


DATA.head()
# Out:
# Offered_band    E0      E1     E2     E3
# Location
# Ahmedabad      0.0     5.0    1.0    0.0
# Bangalore     10.0  1550.0  580.0   90.0
# Chennai       70.0  2145.0  807.0  128.0
# Cochin         0.0     7.0    1.0    0.0
# Gurgaon        0.0    97.0   47.0    2.0

# %%
# making a function which returns 0 or 1
# 0 means SLNO was not in that Location, 1 means SLNO present in that Location

def encode(x):
    if x<=0:
        return 0
    if x>=1:
        return 1

# applying the function to the dataset

DATA_SET = DATA.applymap(encode)
DATA_SET.head()
# Out:
# Offered_band  E0  E1  E2  E3
# Location
# Ahmedabad      0   1   1   0
# Bangalore      1   1   1   1
# Chennai        1   1   1   1
# Cochin         0   1   1   0
# Gurgaon        0   1   1   1

# %%
# using the 'apriori algorithm' with min_support=0.01 (1% of 9465)
# It means the item should be present in atleast 94 transaction out of 9465 transactions only when we considered that item in
# frequent itemset
frequent_Location = apriori(DATA_SET, min_support = 0.01,use_colnames = True)
frequent_Location
# Out:
#      support          itemsets
# 0   0.363636              (E0)
# 1   1.000000              (E1)
# 2   1.000000              (E2)
# 3   0.727273              (E3)
# 4   0.363636          (E1, E0)
# 5   0.363636          (E2, E0)
# 6   0.363636          (E3, E0)
# 7   1.000000          (E2, E1)
# 8   0.727273          (E3, E1)
# 9   0.727273          (E3, E2)
# 10  0.363636      (E2, E1, E0)
# 11  0.363636      (E3, E1, E0)
# 12  0.363636      (E3, E2, E0)
# 13  0.727273      (E3, E2, E1)
# 14  0.363636  (E3, E2, E1, E0)

# %%
# now making the rules from frequent itemset generated above

# Association rules are created by searching data for frequent if-then patterns and using
#the criteria support and confidence to identify the most important relationships.
rules = association_rules(frequent_Location, metric = "lift", min_threshold = 1)
rules.sort_values('confidence', ascending = False, inplace = True)
rules
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 25      (E3, E0)          (E2)            0.363636            1.000000
# 31      (E3, E1)          (E2)            0.727273            1.000000
# 20      (E1, E0)          (E3)            0.363636            0.727273
# 23          (E0)      (E3, E1)            0.363636            0.727273
# 1           (E0)          (E1)            0.363636            1.000000
# 26      (E2, E0)          (E3)            0.363636            0.727273
# 29          (E0)      (E3, E2)            0.363636            0.727273
# 30      (E3, E2)          (E1)            0.727273            1.000000
# 33          (E3)      (E2, E1)            0.727273            1.000000
# 17          (E0)      (E2, E1)            0.363636            1.000000
# 37  (E3, E2, E0)          (E1)            0.363636            1.000000
# 38  (E3, E1, E0)          (E2)            0.363636            1.000000
# ...

# %%
# arranging the data from highest to lowest with respect to 'confidence'

rules.sort_values('confidence', ascending=False)
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 25      (E3, E0)          (E2)            0.363636            1.000000
# 44      (E2, E0)      (E3, E1)            0.363636            0.727273
# 31      (E3, E1)          (E2)            0.727273            1.000000
# 10          (E3)          (E2)            0.727273            1.000000
# 13      (E2, E0)          (E1)            0.363636            1.000000
# 14      (E1, E0)          (E2)            0.363636            1.000000
# 8           (E3)          (E1)            0.727273            1.000000
# 3           (E0)          (E2)            0.363636            1.000000
# 7           (E1)          (E2)            1.000000            1.000000
# 5           (E0)          (E3)            0.363636            0.727273
# 49          (E0)  (E3, E2, E1)            0.363636            0.727273
# 19      (E3, E0)          (E1)            0.363636            1.000000
# ...
